# %%
# !git clone https://github.com/huggingface/transformers.git
# !cd transformers
# !pip install transformers
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 141, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 22836 (delta 71), reused 110 (delta 47), pack-reused 22695
# Receiving objects: 100% (22836/22836), 13.43 MiB | 24.87 MiB/s, done.
# Resolving deltas: 100% (16344/16344), done.
# ...
#      |████████████████████████████████| 542kB 2.8MB/s
# ...
#      |████████████████████████████████| 870kB 44.1MB/s
# ...
#      |████████████████████████████████| 1.0MB 25.6MB/s
# ...
#      |████████████████████████████████| 3.7MB 37.9MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.38-cp36-none-any.whl size=884628 sha256=b57e04de9101da6402200755261e8dd9c8c45907a06ce3caa1ae9865a429eaf0
#   Stored in directory: /root/.cache/pip/wheels/6d/ec/1a/21b8912e35e02741306f35f66c785f3afe94de754a0eaf1422
# Successfully built sacremoses
# ...

# %%
# !python3 run_language_modeling.py \
--train_data_file "drive/My Drive/266_train/raw L2/L2_7topics.txt" \
--output_dir "drive/My Drive/266_train/test/pretrained_l2/7topics_2e-5" \
--model_type "bert" \
--mlm \
--model_name_or_path "drive/My Drive/266_train/test/pretrained_results_10k/finalL1only_1e-4learningrate" \
--num_train_epochs 4 \
--learning_rate 2e-5 \
--per_gpu_train_batch_size 8 \
--do_train \
--block_size 512 \
--seed 42
# Out:
# 03/25/2020 02:02:31 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 03/25/2020 02:02:31 - INFO - transformers.configuration_utils -   loading configuration file drive/My Drive/266_train/test/pretrained_results_10k/finalL1only_1e-4learningrate/config.json
# 03/25/2020 02:02:31 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "eos_token_ids": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
# ...
